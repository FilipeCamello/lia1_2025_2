# %% [markdown]
# <a href="https://colab.research.google.com/github/FilipeCamello/lia1_2025_2/blob/main/Aula%2004%20-%20Colab%20e%20VScode/Aula05_Introdu%C3%A7%C3%A3o_ao_Python_com_GitHub_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <hr>
# <div class="container">
#     <img src='https://github.com/scadriano/datascience/blob/main/datascienceintroduce/header.png?raw=true' align='left' width='180'  height='200' />
# </div>
#
# <h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div>  2024/1 | 24M34 | Sala 200 CAE</ </div>
# <hr>
#
# <h2> Introdução ao Python com Github - Colab </h2>
# Notebook desenvolvido por: <a href="http://lattes.cnpq.br/1346824250595330">Prof. Dr. Adriano C. Santana</a>
#
# <hr>

# %%
# Conexão com o Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Confirmar a versão da Linguagem Python instalada
from platform import python_version
print(f'A versão da linguagem Python usada neste projeto é a {python_version()}!')
#python_version()
# Out:
# A versão da linguagem Python usada neste projeto é a 3.12.11!

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# # Manipulando arquivos

# %% [markdown]
# ### Lendo arquivos (.txt)

# %%
# Abrindo o arquivo para leitura
a1 = open("/content/drive/MyDrive/Documentos LIA/Arquivo 01 20-08.txt", "r")

# %%
# Escrevendo a variável a1
print(a1.read())
# Out:
# Estudando o colab 2025

# %% [markdown]
# ### Gravando arquivos (.txt)

# %%
# Abrindo o arquivo para escrita
a2 = open("/content/drive/MyDrive/Documentos LIA/Arquivo 02 20-08.txt", "w")

# %%
# Gravando no arquivo
a2.write("Aprendendo Python 1 - 01/04!")
# Out:
# 28

# %%
# Abrindo o arquivo para leitura - no content (temporário)
a2 = open("/content/drive/MyDrive/Documentos LIA/Arquivo 02 20-08.txt", "r")

# %%
# Imprimindo arquivo
print(a2.read())
# Out:
# Aprendendo Python 1 - 01/04!

# %% [markdown]
# # Manipulando datasets

# %%
# importar o arquivo e guardar em um dataframe do Pandas
import pandas as pd
df = pd.read_csv ('/content/drive/MyDrive/Documentos LIA/hospital.csv', sep=',', index_col=None)
df2 = pd.read_csv ('/content/drive/MyDrive/UCMF_raw_data.csv', sep=',', index_col=None)

# %%
# exibir o dataframe
df
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temperatura  Internação  \
# 0  4201     João     28    M    79  Concentradas         38.0           2
# 1  3217    Maria     18    F    67  Inexistentes         39.5           4
# 2  4039     Luiz     49    M    92    Espalhadas         38.0           2
# 3  1920     José     18    M    43  Inexistentes         38.5           8
# 4  4340  Cláudia     21    F    52     Uniformes         37.6           1
# 5  2301      Ana     22    F    72  Inexistentes         38.0           3
# 6  1322    Marta     19    F    87    Espalhadas         39.0           6
# 7  3027    Paulo     34    M    67     Uniformes         38.4           2
#
#   Estado       Time Diagnóstico
# 0     SP  Palmeiras      Doente
# 1     MG   Cruzeiro      Doente
# 2     RS     Grêmio    Saudável
# 3     MG   Atlético      Doente
# 4     PE      Sport    Saudável
# 5     RJ   Botafogo      Doente
# 6     AM   Flamengo      Doente
# 7     GO  Vila Nova    Saudável

# %%
df2
# Out:
#           ID  Peso  Altura   IMC Atendimento        DN   IDADE Convenio  \
# 0          1   5.0      51  19.0    11/05/06  30/03/06    0.12       GS
# 1          2   3.5      50  14.0    25/05/05  19/05/05    0.02       GS
# 2          3   0.0       0   NaN    12/06/01  08/05/05   -4.05     SULA
# 3          4   8.1      65  19.0    15/10/09  21/04/09     0.5      NaN
# 4          5  39.5     142  20.0    23/01/09  24/10/99     9.6    Sulam
# ...      ...   ...     ...   ...         ...       ...     ...      ...
# 17868  17869   9.5      76  16.0    03/02/06  06/12/04     1.2      NaN
# 17869  17870  12.0      75  21.0    25/09/09  15/12/08    0.81       UR
# 17870  17871  65.0     175  21.0    03/08/07  16/02/84   24.34   Medial
# 17871  17872  27.0     134  15.0    04/10/04  03/12/27  -24.03       GS
# 17872  17873  44.5       0   NaN    10/07/03  21/07/92   11.38       GS
#
#         PULSOS  PA SISTOLICA  ...            PPA NORMAL X ANORMAL      B2  \
# 0      Normais           NaN  ...  Não Calculado          Anormal  Normal
# 1      Normais           NaN  ...  Não Calculado          Anormal  Normal
# 2      Normais           NaN  ...  Não Calculado          Anormal  Normal
# 3      Normais           NaN  ...  Não Calculado          Anormal  Normal
# 4      Normais          85.0  ...         Normal          Anormal  Normal
# ...        ...           ...  ...            ...              ...     ...
# 17868  Normais           NaN  ...  Não Calculado           Normal  Normal
# 17869  Normais           NaN  ...  Não Calculado           Normal  Normal
# 17870  Normais         126.0  ...  Não Calculado           Normal  Normal
# 17871  Normais          90.0  ...  Não Calculado           Normal  Normal
# 17872  Normais         110.0  ...  Não Calculado          Normais  Normal
#
#            SOPRO   FC           HDA 1 HDA2       SEXO  \
# 0      Sistólico  112      Palpitacao  NaN          M
# 1        ausente  128        Dispneia  NaN          M
# 2      Sistólico   88   Assintomático  NaN          M
# 3        ausente   92   Assintomático  NaN          M
# 4        ausente   90             NaN  NaN          M
# ...          ...  ...             ...  ...        ...
# 17868    ausente   92   Assintomático  NaN  Masculino
# 17869    ausente   90   Assintomático  NaN  Masculino
# 17870    ausente   76  Dor precordial  NaN   Feminino
# 17871  Sistólico  NaN             NaN  NaN   Feminino
# 17872    ausente   80  Dor precordial  NaN   Feminino
#
#                                MOTIVO1                              MOTIVO2
# 0          6 - Suspeita de cardiopatia  6 - Palpitação/taquicardia/arritmia
# 1          6 - Suspeita de cardiopatia                         6 - Dispnéia
# 2                         2 - Check-up                                  NaN
# 3             5 - Parecer cardiológico                                  NaN
# 4             5 - Parecer cardiológico                 5 - Atividade física
# ...                                ...                                  ...
# 17868         5 - Parecer cardiológico                         5 - Cirurgia
# 17869         5 - Parecer cardiológico                         5 - Cirurgia
# 17870  1 - Cardiopatia já estabelecida            1 - Cardiopatia congenica
# 17871      6 - Suspeita de cardiopatia                   6 - Dor precordial
# 17872      6 - Suspeita de cardiopatia                   6 - Dor precordial
#
# [17873 rows x 21 columns]

# %%
# exibir uma amostra do dataframe (head)
display(df.head())
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temperatura  Internação  \
# 0  4201     João     28    M    79  Concentradas         38.0           2
# 1  3217    Maria     18    F    67  Inexistentes         39.5           4
# 2  4039     Luiz     49    M    92    Espalhadas         38.0           2
# 3  1920     José     18    M    43  Inexistentes         38.5           8
# 4  4340  Cláudia     21    F    52     Uniformes         37.6           1
#
#   Estado       Time Diagnóstico
# 0     SP  Palmeiras      Doente
# 1     MG   Cruzeiro      Doente
# 2     RS     Grêmio    Saudável
# 3     MG   Atlético      Doente
# 4     PE      Sport    Saudável

# %%
# exibir uma amostra do dataframe (tail)
display(df.tail())
# Out:
#      Id     Nome  Idade Sexo  Peso       Manchas  Temperatura  Internação  \
# 3  1920     José     18    M    43  Inexistentes         38.5           8
# 4  4340  Cláudia     21    F    52     Uniformes         37.6           1
# 5  2301      Ana     22    F    72  Inexistentes         38.0           3
# 6  1322    Marta     19    F    87    Espalhadas         39.0           6
# 7  3027    Paulo     34    M    67     Uniformes         38.4           2
#
#   Estado       Time Diagnóstico
# 3     MG   Atlético      Doente
# 4     PE      Sport    Saudável
# 5     RJ   Botafogo      Doente
# 6     AM   Flamengo      Doente
# 7     GO  Vila Nova    Saudável

# %%
# Agrupar por 'Diagnóstico', mostrando as ocorrências
df.groupby('Diagnóstico').count().plot.pie(y = 'Internação');

# %%
df2.groupby('PPA').count().plot.pie(y= 'ID');

# %%
# Qual time tem mais Doentes? :)
df_doente = df[df['Diagnóstico'] == 'Doente']
time_mais_doente = df_doente['Time'].value_counts().idxmax()
print("O time com o maior número de diagnósticos 'Doente' é o",time_mais_doente,"!")
# Out:
# O time com o maior número de diagnósticos 'Doente' é o Palmeiras !

# %% [markdown]
# Enfim, logo estudaremos **Ciência de Dados** e as análises dependerão dos objetivos e das perguntas que **desejamos responder com os dados**!
